# %% [markdown]
# # Estadística Aplicada
# ## Andrik Daniel Vazquez Regalado 1905622
# ### 3era Sesión 1ero de febrero

# %% [markdown]
# ## TUPLAS
# es una colección de objetos inmutables (que no se pueden cambiar)

# %%
tupla1 = ("Juan","Miguel",23)

# %%
tupla1
# Out:
# ('Juan', 'Miguel', 23)

# %%
tupla1[1]
# Out:
# 'Miguel'

# %% [markdown]
# ## Diccionarios
# ## clave-valor(es)

# %%
estadistica_g5 = {"Nombre" : ["Juan", "Jime", "Ale"], "Edad": [17,22,15]}

# %%
estadistica_g5
# Out:
# {'Nombre': ['Juan', 'Jime', 'Ale'], 'Edad': [17, 22, 15]}

# %%
estadistica_g5.keys()
# Out:
# dict_keys(['Nombre', 'Edad'])

# %%
estadistica_g5.values()
# Out:
# dict_values([['Juan', 'Jime', 'Ale'], [17, 22, 15]])

# %%
estadistica_g5["Nombre"]
# Out:
# ['Juan', 'Jime', 'Ale']

# %% [markdown]
# # Pandas

# %%
import numpy as np
import pandas as pd

# %%
alumno1 = ["Juan", "Perez", 23]
alumno2 = ["Ale", "Solis", 17]
alumno3 = ["Jime", "Garza", 18]
alumno4 = ["Raul", "Lara", 26]

# %%
estadistica = [alumno1, alumno2, alumno3, alumno4]

# %%
estadistica
# Out:
# [['Juan', 'Perez', 23],
#  ['Ale', 'Solis', 17],
#  ['Jime', 'Garza', 18],
#  ['Raul', 'Lara', 26]]

# %%
# vamos a convertirla en dataframe
estadistica = pd.DataFrame(estadistica, columns = ["Nombre", "Apellido", "Edad"])

# %%
estadistica
# Out:
#   Nombre Apellido  Edad
# 0   Juan    Perez    23
# 1    Ale    Solis    17
# 2   Jime    Garza    18
# 3   Raul     Lara    26

# %%
estadistica.columns
# Out:
# Index(['Nombre', 'Apellido', 'Edad'], dtype='object')

# %%
estadistica.index
# Out:
# RangeIndex(start=0, stop=4, step=1)

# %%
estadistica['Edad en dias'] = estadistica['Edad']*(365)

# %%
estadistica
# Out:
#   Nombre Apellido  Edad  Edad en dias
# 0   Juan    Perez    23          8395
# 1    Ale    Solis    17          6205
# 2   Jime    Garza    18          6570
# 3   Raul     Lara    26          9490

# %%
estadistica["origen"] = ["Apodaca", "Escobedo", "San Pedro", "Montemorelos"]

# %%
estadistica
# Out:
#   Nombre Apellido  Edad  Edad en dias        origen
# 0   Juan    Perez    23          8395       Apodaca
# 1    Ale    Solis    17          6205      Escobedo
# 2   Jime    Garza    18          6570     San Pedro
# 3   Raul     Lara    26          9490  Montemorelos

# %%
estadistica["Edad"]
# Out:
# 0    23
# 1    17
# 2    18
# 3    26
# Name: Edad, dtype: int64

# %%
estadistica[["Nombre","Edad"]]
# Out:
#   Nombre  Edad
# 0   Juan    23
# 1    Ale    17
# 2   Jime    18
# 3   Raul    26

# %%
estadistica[0:2]
# Out:
#   Nombre Apellido  Edad  Edad en dias    origen
# 0   Juan    Perez    23          8395   Apodaca
# 1    Ale    Solis    17          6205  Escobedo

# %%
estadistica[0:2] ["Nombre"]
# Out:
# 0    Juan
# 1     Ale
# Name: Nombre, dtype: object

# %%
estadistica[0:2] [["Nombre", "Edad"]]
# Out:
#   Nombre  Edad
# 0   Juan    23
# 1    Ale    17

# %%
estadistica.iloc[:, 2]
# Out:
# 0    23
# 1    17
# 2    18
# 3    26
# Name: Edad, dtype: int64

# %%
estadistica.iloc[:, 0]
# Out:
# 0    Juan
# 1     Ale
# 2    Jime
# 3    Raul
# Name: Nombre, dtype: object

# %%
estadistica.iloc[:, [0,2]]
# Out:
#   Nombre  Edad
# 0   Juan    23
# 1    Ale    17
# 2   Jime    18
# 3   Raul    26

# %%
estadistica.iloc[0, [0,2]]
# Out:
# Nombre    Juan
# Edad        23
# Name: 0, dtype: object

# %%
estadistica
# Out:
#   Nombre Apellido  Edad  Edad en dias        origen
# 0   Juan    Perez    23          8395       Apodaca
# 1    Ale    Solis    17          6205      Escobedo
# 2   Jime    Garza    18          6570     San Pedro
# 3   Raul     Lara    26          9490  Montemorelos

# %%
estadistica.loc[:,["Nombre","Apellido"]]
# Out:
#   Nombre Apellido
# 0   Juan    Perez
# 1    Ale    Solis
# 2   Jime    Garza
# 3   Raul     Lara

# %%
estadistica.Edad
# Out:
# 0    23
# 1    17
# 2    18
# 3    26
# Name: Edad, dtype: int64

# %%
estadistica.Nombre
# Out:
# 0    Juan
# 1     Ale
# 2    Jime
# 3    Raul
# Name: Nombre, dtype: object

# %%
estadistica_g5
# Out:
# {'Nombre': ['Juan', 'Jime', 'Ale'], 'Edad': [17, 22, 15]}

# %%
 estadistica_g5 = pd.DataFrame(estadistica_g5)

# %%
estadistica_g5
# Out:
#   Nombre  Edad
# 0   Juan    17
# 1   Jime    22
# 2    Ale    15

# %%
archivo_excel = pd.read_excel("C:/Users/Lenovo/Documents/ESTADISTICA.xlsx")

# %%
Calificaciones = pd.read_csv("https://raw.githubusercontent.com/jimmyzac/Estadistica-Aplicada-FCFM-UANL/main/bases_datos/Calificaciones.csv")

# %%
Calificaciones
# Out:
#     Id            Nombre   Apellido  Calficación Final
# 0    1           ANTONIO     GARCIA                 73
# 1    2            MANUEL  FERNANDEZ                 19
# 2    3              JOSE   GONZALEZ                 38
# 3    4             DAVID      PEREZ                 14
# 4    5              JUAN      LOPEZ                 99
# 5    6      JOSE ANTONIO  RODRIGUEZ                 66
# 6    7            JAVIER    SANCHEZ                 46
# 7    8         JOSE LUIS      GOMEZ                 89
# 8    9  FRANCISCO JAVIER    JIMENEZ                 10
# 9   10            CARLOS       RUIZ                 62
# 10  11             JESUS     ALONSO                 94
# 11  12         ALEJANDRO  HERNANDEZ                 17
# 12  13            MIGUEL       DIAZ                 85
# 13  14       JOSE MANUEL  GUTIERREZ                 34
# 14  15            RAFAEL    ALVAREZ                 86
# 15  16      MIGUEL ANGEL     MORENO                100
# ...

# %%
Calificaciones.head() #primeras 5 observaciones
# Out:
#    Id   Nombre   Apellido  Calficación Final
# 0   1  ANTONIO     GARCIA                 73
# 1   2   MANUEL  FERNANDEZ                 19
# 2   3     JOSE   GONZALEZ                 38
# 3   4    DAVID      PEREZ                 14
# 4   5     JUAN      LOPEZ                 99

# %%
Calificaciones.head(4)
# Out:
#    Id   Nombre   Apellido  Calficación Final
# 0   1  ANTONIO     GARCIA                 73
# 1   2   MANUEL  FERNANDEZ                 19
# 2   3     JOSE   GONZALEZ                 38
# 3   4    DAVID      PEREZ                 14

# %%
Calificaciones.tail() #ultimas 5 observaciones
# Out:
#     Id       Nombre   Apellido  Calficación Final
# 23  24         LUIS  DOMINGUEZ                 12
# 24  25      ALBERTO      ORTIZ                 99
# 25  26  JUAN CARLOS     IBAÑEZ                 43
# 26  27       ALVARO    RAMIREZ                 40
# 27  28       ADRIAN       SAEZ                  7

# %%
Calificaciones.tail(8)
# Out:
#     Id       Nombre   Apellido  Calficación Final
# 20  21   JOSE MARIA       DIEZ                 29
# 21  22     FERNANDO    SALAZAR                 51
# 22  23        JORGE      RAMOS                 76
# 23  24         LUIS  DOMINGUEZ                 12
# 24  25      ALBERTO      ORTIZ                 99
# 25  26  JUAN CARLOS     IBAÑEZ                 43
# 26  27       ALVARO    RAMIREZ                 40
# 27  28       ADRIAN       SAEZ                  7

# %%
Calificaciones.shape #Cuantas filas y columnas tiene el DATA FRAME
# Out:
# (28, 4)

# %%
Calificaciones.columns
# Out:
# Index(['Id', 'Nombre', 'Apellido', 'Calficación Final'], dtype='object')

# %%
Calificaciones.index
# Out:
# RangeIndex(start=0, stop=28, step=1)

# %%
Calificaciones.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 28 entries, 0 to 27
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id                 28 non-null     int64
#  1   Nombre             28 non-null     object
#  2   Apellido           28 non-null     object
#  3   Calficación Final  28 non-null     int64
# dtypes: int64(2), object(2)
# memory usage: 1.0+ KB

# %%
Calificaciones.describe() #nos da las estadisticas descriptivas
# Out:
#               Id  Calficación Final
# count  28.000000          28.000000
# mean   14.500000          52.000000
# std     8.225975          34.113102
# min     1.000000           1.000000
# 25%     7.750000          18.500000
# 50%    14.500000          48.500000
# 75%    21.250000          85.250000
# max    28.000000         100.000000

# %%
Calificaciones
# Out:
#     Id            Nombre   Apellido  Calficación Final
# 0    1           ANTONIO     GARCIA                 73
# 1    2            MANUEL  FERNANDEZ                 19
# 2    3              JOSE   GONZALEZ                 38
# 3    4             DAVID      PEREZ                 14
# 4    5              JUAN      LOPEZ                 99
# 5    6      JOSE ANTONIO  RODRIGUEZ                 66
# 6    7            JAVIER    SANCHEZ                 46
# 7    8         JOSE LUIS      GOMEZ                 89
# 8    9  FRANCISCO JAVIER    JIMENEZ                 10
# 9   10            CARLOS       RUIZ                 62
# 10  11             JESUS     ALONSO                 94
# 11  12         ALEJANDRO  HERNANDEZ                 17
# 12  13            MIGUEL       DIAZ                 85
# 13  14       JOSE MANUEL  GUTIERREZ                 34
# 14  15            RAFAEL    ALVAREZ                 86
# 15  16      MIGUEL ANGEL     MORENO                100
# ...

# %%
Calificaciones.set_index("Apellido")
# Out:
#            Id            Nombre  Calficación Final
# Apellido
# GARCIA      1           ANTONIO                 73
# FERNANDEZ   2            MANUEL                 19
# GONZALEZ    3              JOSE                 38
# PEREZ       4             DAVID                 14
# LOPEZ       5              JUAN                 99
# RODRIGUEZ   6      JOSE ANTONIO                 66
# SANCHEZ     7            JAVIER                 46
# GOMEZ       8         JOSE LUIS                 89
# JIMENEZ     9  FRANCISCO JAVIER                 10
# RUIZ       10            CARLOS                 62
# ALONSO     11             JESUS                 94
# HERNANDEZ  12         ALEJANDRO                 17
# DIAZ       13            MIGUEL                 85
# GUTIERREZ  14       JOSE MANUEL                 34
# ALVAREZ    15            RAFAEL                 86
# MORENO     16      MIGUEL ANGEL                100
# MUÑOZ      17             PEDRO                  1
# ...

# %%
Calificaciones.rename(columns = {"Calficación Final" : "cal_final", "Nombre" : "nombre", "Id": "id", "Apellido":"apellido"}, inplace=True)

# %%
Calificaciones.head()
# Out:
#    id   nombre   apellido  cal_final
# 0   1  ANTONIO     GARCIA         73
# 1   2   MANUEL  FERNANDEZ         19
# 2   3     JOSE   GONZALEZ         38
# 3   4    DAVID      PEREZ         14
# 4   5     JUAN      LOPEZ         99

# %%
Calificaciones["cal_final"].mean()
# Out:
# 52.0

# %%
Calificaciones["situación"] = np.where(Calificaciones["cal_final"]>=70, "Aprobado", "Reprobado")

# %%
Calificaciones.head()
# Out:
#    id   nombre   apellido  cal_final  situación
# 0   1  ANTONIO     GARCIA         73   Aprobado
# 1   2   MANUEL  FERNANDEZ         19  Reprobado
# 2   3     JOSE   GONZALEZ         38  Reprobado
# 3   4    DAVID      PEREZ         14  Reprobado
# 4   5     JUAN      LOPEZ         99   Aprobado

# %%
Calificaciones.groupby("situación").count() ["cal_final"]
# Out:
# situación
# Aprobado     10
# Reprobado    18
# Name: cal_final, dtype: int64

# %%
Calificaciones.groupby("situación").mean() ["cal_final"]
# Out:
# situación
# Aprobado     90.100000
# Reprobado    30.833333
# Name: cal_final, dtype: float64

# %%
excelentes = Calificaciones[Calificaciones["cal_final"]>=90]

# %%
excelentes
# Out:
#     id        nombre apellido  cal_final situación
# 4    5          JUAN    LOPEZ         99  Aprobado
# 10  11         JESUS   ALONSO         94  Aprobado
# 15  16  MIGUEL ANGEL   MORENO        100  Aprobado
# 18  19         ANGEL      GIL        100  Aprobado
# 24  25       ALBERTO    ORTIZ         99  Aprobado

# %%
Calificaciones.value_counts("situación")
# Out:
# situación
# Reprobado    18
# Aprobado     10
# dtype: int64

# %%
Calificaciones.sort_values("cal_final", ascending=False) #Mayor a menor
# Out:
#     id            nombre   apellido  cal_final  situación
# 18  19             ANGEL        GIL        100   Aprobado
# 15  16      MIGUEL ANGEL     MORENO        100   Aprobado
# 24  25           ALBERTO      ORTIZ         99   Aprobado
# 4    5              JUAN      LOPEZ         99   Aprobado
# 10  11             JESUS     ALONSO         94   Aprobado
# 7    8         JOSE LUIS      GOMEZ         89   Aprobado
# 14  15            RAFAEL    ALVAREZ         86   Aprobado
# 12  13            MIGUEL       DIAZ         85   Aprobado
# 22  23             JORGE      RAMOS         76   Aprobado
# 0    1           ANTONIO     GARCIA         73   Aprobado
# 5    6      JOSE ANTONIO  RODRIGUEZ         66  Reprobado
# 17  18             PABLO     BLANCO         64  Reprobado
# 9   10            CARLOS       RUIZ         62  Reprobado
# 21  22          FERNANDO    SALAZAR         51  Reprobado
# 6    7            JAVIER    SANCHEZ         46  Reprobado
# ...

# %%
Calificaciones = Calificaciones.sort_values(["apellido", "nombre"], ascending=[True,True]) #DE LA "A" a LA "Z"

# %%
Calificaciones
# Out:
#     id            nombre   apellido  cal_final  situación
# 19  20            SERGIO    AGUIRRE          2  Reprobado
# 10  11             JESUS     ALONSO         94   Aprobado
# 14  15            RAFAEL    ALVAREZ         86   Aprobado
# 17  18             PABLO     BLANCO         64  Reprobado
# 12  13            MIGUEL       DIAZ         85   Aprobado
# 20  21        JOSE MARIA       DIEZ         29  Reprobado
# 23  24              LUIS  DOMINGUEZ         12  Reprobado
# 1    2            MANUEL  FERNANDEZ         19  Reprobado
# 0    1           ANTONIO     GARCIA         73   Aprobado
# 18  19             ANGEL        GIL        100   Aprobado
# 7    8         JOSE LUIS      GOMEZ         89   Aprobado
# 2    3              JOSE   GONZALEZ         38  Reprobado
# 13  14       JOSE MANUEL  GUTIERREZ         34  Reprobado
# 11  12         ALEJANDRO  HERNANDEZ         17  Reprobado
# 25  26       JUAN CARLOS     IBAÑEZ         43  Reprobado
# ...
